# %% [markdown]
# ## This project aims to predict any need for treatment to complete vascularization in neonates with retinopathy of prematurity (ROP)
#
# ### event1 = y (labels)
# event1 has two values :
# 1: a treatment, either intravitreal bevacizumab or laser photocoagulation, has been utilized for the neonate
# 0: retinal vascularization completed without any treatment
#
# ### Features were defined as follows (features were selected as the domain expert recommendation at this step):
# #### Sex: binary
# #### Mother_Education: ordinary
# #### Father_Education: ordinary
# #### CPR: binary
# #### low_Apgar: binary
# #### Birth_Age: continuous
# #### Birth_Weight: continuous
# #### NICU_Time: continuous
# #### Age: continuous
# #### Weight: continuous
# #### ROP_Stage: ordinary
# #### ROP_Zone: ordinary
# #### Plus: binary {1=plus, 2=No plus}

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import xgboost as xgb

# %%
ROP_Dataset = pd.read_csv("DataSet-ROP.csv")

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
ROP_Dataset.head()
# Out:
#    Patient_ID  event1  Sex  Mother_Education  Father_Education  CPR  \
# 0  A-00-82-02       1    2               NaN               NaN    2
# 1  A-00-82-13       1    2               NaN               NaN    2
# 2  A-00-82-82       1    2               NaN               NaN    2
# 3  A-00-82-84       1    1               NaN               NaN    2
# 4  A-00-82-99       1    2               NaN               NaN    2
#
#    low_Apgar  Birth_Age  Birth_Weight  NICU_Time   Age  weight  OD_ROP_Stage  \
# 0          2       29.0        2000.0       50.0  37.0  2100.0           2.0
# 1          2       30.0        1280.0       18.0  35.0     NaN           2.0
# 2          2       26.0         750.0       65.0  35.0  1620.0           2.0
# 3          2       30.0        1320.0       12.0  36.0  2500.0           2.0
# 4          2       29.0        1350.0        0.0  38.0  1650.0           1.0
#
#    OD_ROP_Zone  OD_Plus
# 0          2.0      2.0
# 1          2.0      NaN
# 2          2.0      2.0
# 3          2.0      2.0
# 4          1.0      1.0

# %%
ROP_Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9692 entries, 0 to 9691
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Patient_ID        9692 non-null   object
#  1   event1            9692 non-null   int64
#  2   Sex               9692 non-null   int64
#  3   Mother_Education  7468 non-null   float64
#  4   Father_Education  7467 non-null   float64
#  5   CPR               9692 non-null   int64
#  6   low_Apgar         9692 non-null   int64
#  7   Birth_Age         9671 non-null   float64
#  8   Birth_Weight      9682 non-null   float64
#  9   NICU_Time         9687 non-null   float64
#  10  Age               7547 non-null   float64
#  11  weight            7769 non-null   float64
#  12  OD_ROP_Stage      7866 non-null   float64
#  13  OD_ROP_Zone       7894 non-null   float64
#  14  OD_Plus           5064 non-null   float64
# dtypes: float64(10), int64(4), object(1)
# memory usage: 1.1+ MB

# %%
ROP_Dataset.shape
# Out:
# (9692, 15)

# %%
ROP_Dataset.describe()
# Out:
#             event1          Sex  Mother_Education  Father_Education  \
# count  9692.000000  9692.000000       7468.000000       7467.000000
# mean      0.044160     1.530231          2.032003          2.012857
# std       0.205461     0.499111          1.235786          1.246198
# min       0.000000     1.000000          1.000000          1.000000
# 25%       0.000000     1.000000          1.000000          1.000000
# 50%       0.000000     2.000000          2.000000          2.000000
# 75%       0.000000     2.000000          2.000000          2.000000
# max       1.000000     2.000000          6.000000          6.000000
#
#                CPR    low_Apgar    Birth_Age  Birth_Weight    NICU_Time  \
# count  9692.000000  9692.000000  9671.000000   9682.000000  9687.000000
# mean      1.998762     1.999484    32.707786   1812.117538    12.798080
# std       0.035167     0.022709     2.521802    501.403679    12.909448
# min       1.000000     1.000000    25.000000    560.000000     0.000000
# 25%       2.000000     2.000000    31.000000   1500.000000     5.000000
# 50%       2.000000     2.000000    33.000000   1800.000000     9.000000
# 75%       2.000000     2.000000    34.000000   2090.000000    16.000000
# max       2.000000     2.000000    38.000000   4000.000000    96.000000
#
#                Age        weight  OD_ROP_Stage  OD_ROP_Zone      OD_Plus
# count  7547.000000   7769.000000   7866.000000  7894.000000  5064.000000
# mean     37.403604   2434.640366      0.863717     2.503547     1.975513
# std       2.638996    820.008230      0.823209     0.533367     0.154569
# min      29.000000    700.000000      0.000000     1.000000     1.000000
# 25%      36.000000   1900.000000      0.000000     2.000000     2.000000
# 50%      37.000000   2300.000000      1.000000     3.000000     2.000000
# 75%      39.000000   2800.000000      2.000000     3.000000     2.000000
# max      44.000000  11000.000000      5.000000     3.000000     2.000000

# %% [markdown]
# ### "event1" is the label y

# %%
ROP_Dataset["event1"].value_counts()
# Out:
# event1
# 0    9264
# 1     428
# Name: count, dtype: int64

# %% [markdown]
# ### Let's look at the features

# %%
ROP_Dataset["Sex"].value_counts()
# Out:
# Sex
# 2    5139
# 1    4553
# Name: count, dtype: int64

# %%
ROP_Dataset["Mother_Education"].value_counts()
# Out:
# Mother_Education
# 1.0    3384
# 2.0    2280
# 4.0    1200
# 3.0     319
# 5.0     236
# 6.0      49
# Name: count, dtype: int64

# %%
ROP_Dataset["Father_Education"].value_counts()
# Out:
# Father_Education
# 1.0    3446
# 2.0    2278
# 4.0     996
# 3.0     380
# 5.0     298
# 6.0      69
# Name: count, dtype: int64

# %%
ROP_Dataset["CPR"].value_counts()
# Out:
# CPR
# 2    9680
# 1      12
# Name: count, dtype: int64

# %%
ROP_Dataset["low_Apgar"].value_counts()
# Out:
# low_Apgar
# 2    9687
# 1       5
# Name: count, dtype: int64

# %%
ROP_Dataset["OD_ROP_Stage"].value_counts()
# Out:
# OD_ROP_Stage
# 0.0    3232
# 1.0    2496
# 2.0    2130
# 5.0       6
# 4.0       2
# Name: count, dtype: int64

# %%
ROP_Dataset["OD_ROP_Zone"].value_counts()
# Out:
# OD_ROP_Zone
# 3.0    4111
# 2.0    3647
# 1.0     136
# Name: count, dtype: int64

# %%
ROP_Dataset["OD_Plus"].value_counts()
# Out:
# OD_Plus
# 2.0    4940
# 1.0     124
# Name: count, dtype: int64

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Distribution plots of features with continuous scale

# %%
sns.displot(ROP_Dataset, x="Birth_Age", kind="kde")

# %%
sns.displot(ROP_Dataset, x="Birth_Weight", kind="kde")

# %%
sns.displot(ROP_Dataset, x="Age", kind="kde")

# %%
sns.displot(ROP_Dataset, x="weight", kind="kde")

# %%
sns.displot(ROP_Dataset, x="NICU_Time", kind="kde")

# %% [markdown]
# ### Bar-plot for qualitative variables

# %%
sns.displot(ROP_Dataset, x="Sex", shrink=1)

# %%
sns.displot(ROP_Dataset, x="Mother_Education", shrink=2)

# %%
sns.displot(ROP_Dataset, x="Father_Education", shrink=2)

# %%
sns.displot(ROP_Dataset, x="CPR", shrink=2)

# %%
sns.displot(ROP_Dataset, x="low_Apgar", shrink=2)

# %%
sns.displot(ROP_Dataset, x="OD_ROP_Stage", shrink=2)

# %%
sns.displot(ROP_Dataset, x="OD_ROP_Zone", shrink=2)

# %%
sns.displot(ROP_Dataset, x="OD_Plus", shrink=2)

# %% [markdown]
# ### Pairplot analysis to evaluate the pairwise comparison between the features

# %%
sns.pairplot(ROP_Dataset[["Sex","Mother_Education","Father_Education","CPR","low_Apgar","Birth_Age","Birth_Weight","NICU_Time","Age","weight","OD_ROP_Stage","OD_ROP_Zone","OD_Plus","event1"]])
plt.show()

# %% [markdown]
# ### Correlation analysis

# %%
corr = ROP_Dataset[["Sex","Mother_Education","Father_Education","low_Apgar","CPR","Birth_Age","Birth_Weight","NICU_Time","Age","weight","OD_ROP_Stage","OD_ROP_Zone","OD_Plus","event1"]].corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr, cmap='viridis', annot=True)
# Out:
# <Axes: >

# %%
sns.displot(ROP_Dataset, x="NICU_Time", hue='event1',kind="kde")

# %%
sns.boxplot(x="event1", y="NICU_Time", data=ROP_Dataset)
# Out:
# <Axes: xlabel='event1', ylabel='NICU_Time'>

# %%
sns.boxplot(x="event1", y="Birth_Age", data=ROP_Dataset)
# Out:
# <Axes: xlabel='event1', ylabel='Birth_Age'>

# %%
sns.boxplot(x="event1", y="Birth_Weight", data=ROP_Dataset)
# Out:
# <Axes: xlabel='event1', ylabel='Birth_Weight'>

# %% [markdown]
# ## Handling missing values

# %%
ROP_Dataset = ROP_Dataset[["Sex","Mother_Education","Father_Education","CPR","low_Apgar","Birth_Age","Birth_Weight","NICU_Time","Age","weight","OD_ROP_Stage","OD_ROP_Zone","OD_Plus","event1"]]

# %%
ROP_Dataset.fillna(ROP_Dataset.mean(), inplace=True)

# %%
ROP_Dataset.isnull().sum()
# Out:
# Sex                 0
# Mother_Education    0
# Father_Education    0
# CPR                 0
# low_Apgar           0
# Birth_Age           0
# Birth_Weight        0
# NICU_Time           0
# Age                 0
# weight              0
# OD_ROP_Stage        0
# OD_ROP_Zone         0
# OD_Plus             0
# event1              0
# dtype: int64

# %% [markdown]
# ### Prepare Data for Machine learning and Feature Scaling

# %%
X = ROP_Dataset[["Sex","Mother_Education","Father_Education","CPR","low_Apgar","Birth_Age","Birth_Weight","NICU_Time","Age","weight","OD_ROP_Stage","OD_ROP_Zone","OD_Plus"]]
Y = ROP_Dataset[["event1"]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 1)

# %%
y_train.value_counts()
# Out:
# event1
# 0         7421
# 1          332
# Name: count, dtype: int64

# %%
y_test.value_counts()
# Out:
# event1
# 0         1843
# 1           96
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # ADASYN

# %%
from imblearn.over_sampling import ADASYN

# %%
ada = ADASYN(
    sampling_strategy = 'auto',  # samples only from minority class
    random_state = 0,  # for reproducibility
    n_neighbors= 5
)  

X_train, y_train = ada.fit_resample(X_train, y_train)

# %% [markdown]
# ## Training the models

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
knn.score(X_test, y_test)
# Out:
# C:\Users\user\miniconda3\lib\site-packages\sklearn\neighbors\_classification.py:233: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.8947911294481692

# %% [markdown]
# #### Model Evaluation Metrics

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.91      0.94      1843
#            1       0.27      0.64      0.37        96
#
#     accuracy                           0.89      1939
#    macro avg       0.62      0.77      0.66      1939
# weighted avg       0.94      0.89      0.91      1939

# %%
cm =confusion_matrix(y_test, y_pred)
sns.heatmap(cm, square=True , annot=True)
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, y_pred) 
roc_auc = auc(fpr, tpr)

# %%
plt.figure()  
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--', label='No Skill')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Treatment-needed ROP Classification (KNN Model)')
plt.legend()
plt.show()

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# C:\Users\user\miniconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred = logreg.predict(X_test)

# %% [markdown]
# #### Model Evaluation Metrics

# %%
from sklearn import metrics
print('The accuracy of Logistic Regression is: ', (metrics.accuracy_score(y_test, y_pred)))
# Out:
# The accuracy of Logistic Regression is:  0.8416709644146467

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[1547  296]
#  [  11   85]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.84      0.91      1843
#            1       0.22      0.89      0.36        96
#
#     accuracy                           0.84      1939
#    macro avg       0.61      0.86      0.63      1939
# weighted avg       0.95      0.84      0.88      1939

# %%
cm =confusion_matrix(y_test, y_pred)
sns.heatmap(cm, square=True , annot=True)
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, y_pred) 
roc_auc = auc(fpr, tpr)

# %%
plt.figure()  
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--', label='No Skill')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Treatment-needed ROP Classification (Logistic Model)')
plt.legend()
plt.show()

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# C:\Users\user\miniconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
y_pred  =  classifier.predict(X_test)

# %% [markdown]
# #### Model Evaluation Metrics

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[902 941]
#  [  1  95]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.49      0.66      1843
#            1       0.09      0.99      0.17        96
#
#     accuracy                           0.51      1939
#    macro avg       0.55      0.74      0.41      1939
# weighted avg       0.95      0.51      0.63      1939

# %%
cm =confusion_matrix(y_test, y_pred)
sns.heatmap(cm, square=True , annot=True)
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, y_pred) 
roc_auc = auc(fpr, tpr)

# %%
plt.figure()  
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--', label='No Skill')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Treatment-needed ROP Classification (Naive-Bayes Model)')
plt.legend()
plt.show()

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='linear')
svclassifier.fit(X_train, y_train)
# Out:
# C:\Users\user\miniconda3\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='linear')

# %%
y_pred = svclassifier.predict(X_test)

# %% [markdown]
# #### Model Evaluation Metrics

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[1510  333]
#  [   8   88]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.82      0.90      1843
#            1       0.21      0.92      0.34        96
#
#     accuracy                           0.82      1939
#    macro avg       0.60      0.87      0.62      1939
# weighted avg       0.96      0.82      0.87      1939

# %%
cm =confusion_matrix(y_test, y_pred)
sns.heatmap(cm, square=True , annot=True)
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, y_pred) 
roc_auc = auc(fpr, tpr)

# %%
plt.figure()  
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--', label='No Skill')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Treatment-needed ROP Classification (SVM Model)')
plt.legend()
plt.show()

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# #### Model Evaluation Metrics

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[1771   72]
#  [  54   42]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      1843
#            1       0.37      0.44      0.40        96
#
#     accuracy                           0.94      1939
#    macro avg       0.67      0.70      0.68      1939
# weighted avg       0.94      0.94      0.94      1939

# %%
cm =confusion_matrix(y_test, y_pred)
sns.heatmap(cm, square=True , annot=True)
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, y_pred) 
roc_auc = auc(fpr, tpr)

# %%
plt.figure()  
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--', label='No Skill')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Treatment-needed ROP Classification (Decision Tree Model)')
plt.legend()
plt.show()

# %% [markdown]
# ## XGBoosting

# %%
from xgboost import XGBClassifier

# %%
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# #### Model Evaluation Metrics

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[1819   24]
#  [  55   41]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1843
#            1       0.63      0.43      0.51        96
#
#     accuracy                           0.96      1939
#    macro avg       0.80      0.71      0.74      1939
# weighted avg       0.95      0.96      0.96      1939

# %%
cm =confusion_matrix(y_test, y_pred)
sns.heatmap(cm, square=True , annot=True)
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, y_pred) 
roc_auc = auc(fpr, tpr)

# %%
plt.figure()  
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--', label='No Skill')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Treatment-needed ROP Classification (XG Boosting Model)')
plt.legend()
plt.show()

# %% [markdown]
# ## Artificial Neural networks (ANN)

# %%
import tensorflow as tf
ann = tf.keras.models.Sequential()
# Out:
# WARNING:tensorflow:From C:\Users\user\miniconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\user\miniconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\user\miniconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
ann.fit(X_train, y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\user\miniconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\user\miniconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 243/243 [==============================] - 2s 2ms/step - loss: 0.6114 - accuracy: 0.6835
# Epoch 2/100
# 243/243 [==============================] - 0s 2ms/step - loss: 0.2233 - accuracy: 0.9572
# Epoch 3/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.1381 - accuracy: 0.9625
# Epoch 4/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.1180 - accuracy: 0.9671
# Epoch 5/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.1096 - accuracy: 0.9671
# Epoch 6/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.1056 - accuracy: 0.9674
# Epoch 7/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.1028 - accuracy: 0.9680
# Epoch 8/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.1010 - accuracy: 0.9674
# Epoch 9/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0994 - accuracy: 0.9685
# Epoch 10/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0984 - accuracy: 0.9687
# Epoch 11/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0976 - accuracy: 0.9680
# Epoch 12/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0963 - accuracy: 0.9694
# Epoch 13/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0958 - accuracy: 0.9684
# Epoch 14/100
# 243/243 [==============================] - 0s 2ms/step - loss: 0.0951 - accuracy: 0.9678
# Epoch 15/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0949 - accuracy: 0.9681
# Epoch 16/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0939 - accuracy: 0.9683
# Epoch 17/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0937 - accuracy: 0.9684
# Epoch 18/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0931 - accuracy: 0.9689
# Epoch 19/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0929 - accuracy: 0.9683
# Epoch 20/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0929 - accuracy: 0.9689
# Epoch 21/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0925 - accuracy: 0.9688
# Epoch 22/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0919 - accuracy: 0.9685
# Epoch 23/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0922 - accuracy: 0.9684
# Epoch 24/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0917 - accuracy: 0.9690
# Epoch 25/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0919 - accuracy: 0.9685
# Epoch 26/100
# 243/243 [==============================] - 0s 2ms/step - loss: 0.0913 - accuracy: 0.9688
# Epoch 27/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.0916 - accuracy: 0.9694
# Epoch 28/100
# 243/243 [==============================] - 0s 2ms/step - loss: 0.0912 - accuracy: 0.9688
# Epoch 29/100
# 243/243 [==============================] - 0s 2ms/step - loss: 0.0914 - accuracy: 0.9689
# Epoch 30/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0912 - accuracy: 0.9688
# Epoch 31/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0913 - accuracy: 0.9683
# Epoch 32/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0911 - accuracy: 0.9683
# Epoch 33/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0911 - accuracy: 0.9693
# Epoch 34/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0907 - accuracy: 0.9696
# Epoch 35/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0908 - accuracy: 0.9679
# Epoch 36/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0909 - accuracy: 0.9683
# Epoch 37/100
# 243/243 [==============================] - 0s 2ms/step - loss: 0.0907 - accuracy: 0.9688
# Epoch 38/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0907 - accuracy: 0.9683
# Epoch 39/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0904 - accuracy: 0.9684
# Epoch 40/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0904 - accuracy: 0.9685
# Epoch 41/100
# 243/243 [==============================] - 0s 2ms/step - loss: 0.0907 - accuracy: 0.9680
# Epoch 42/100
# 243/243 [==============================] - 0s 2ms/step - loss: 0.0903 - accuracy: 0.9684
# Epoch 43/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0907 - accuracy: 0.9675
# Epoch 44/100
# 243/243 [==============================] - 0s 2ms/step - loss: 0.0899 - accuracy: 0.9687
# Epoch 45/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0902 - accuracy: 0.9676
# Epoch 46/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0901 - accuracy: 0.9689
# Epoch 47/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0901 - accuracy: 0.9688
# Epoch 48/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0901 - accuracy: 0.9681
# Epoch 49/100
# 243/243 [==============================] - 0s 2ms/step - loss: 0.0898 - accuracy: 0.9678
# Epoch 50/100
# 243/243 [==============================] - 0s 2ms/step - loss: 0.0899 - accuracy: 0.9685
# Epoch 51/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0899 - accuracy: 0.9687
# Epoch 52/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0897 - accuracy: 0.9683
# Epoch 53/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0899 - accuracy: 0.9685
# Epoch 54/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.0898 - accuracy: 0.9681
# Epoch 55/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0895 - accuracy: 0.9685
# Epoch 56/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0897 - accuracy: 0.9683
# Epoch 57/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0895 - accuracy: 0.9689
# Epoch 58/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0897 - accuracy: 0.9690
# Epoch 59/100
# 243/243 [==============================] - 0s 2ms/step - loss: 0.0894 - accuracy: 0.9688
# Epoch 60/100
# 243/243 [==============================] - 0s 2ms/step - loss: 0.0892 - accuracy: 0.9689
# Epoch 61/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0892 - accuracy: 0.9696
# Epoch 62/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0894 - accuracy: 0.9685
# Epoch 63/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0891 - accuracy: 0.9683
# Epoch 64/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0891 - accuracy: 0.9689
# Epoch 65/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0889 - accuracy: 0.9683
# Epoch 66/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0889 - accuracy: 0.9678
# Epoch 67/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0887 - accuracy: 0.9690
# Epoch 68/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0887 - accuracy: 0.9689
# Epoch 69/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0888 - accuracy: 0.9685
# Epoch 70/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0886 - accuracy: 0.9696
# Epoch 71/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.0887 - accuracy: 0.9684
# Epoch 72/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0886 - accuracy: 0.9687
# Epoch 73/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0882 - accuracy: 0.9689
# Epoch 74/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0886 - accuracy: 0.9693
# Epoch 75/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0882 - accuracy: 0.9692
# Epoch 76/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0882 - accuracy: 0.9697
# Epoch 77/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0884 - accuracy: 0.9693
# Epoch 78/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0882 - accuracy: 0.9690
# Epoch 79/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0880 - accuracy: 0.9690
# Epoch 80/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0879 - accuracy: 0.9692
# Epoch 81/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0881 - accuracy: 0.9684
# Epoch 82/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0878 - accuracy: 0.9694
# Epoch 83/100
# 243/243 [==============================] - 1s 3ms/step - loss: 0.0878 - accuracy: 0.9690
# Epoch 84/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0879 - accuracy: 0.9690
# Epoch 85/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0878 - accuracy: 0.9690
# Epoch 86/100
# 243/243 [==============================] - 0s 2ms/step - loss: 0.0877 - accuracy: 0.9693
# Epoch 87/100
# 243/243 [==============================] - 0s 2ms/step - loss: 0.0876 - accuracy: 0.9689
# Epoch 88/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0874 - accuracy: 0.9688
# Epoch 89/100
# 243/243 [==============================] - 0s 2ms/step - loss: 0.0874 - accuracy: 0.9694
# Epoch 90/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0876 - accuracy: 0.9693
# Epoch 91/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0876 - accuracy: 0.9694
# Epoch 92/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0875 - accuracy: 0.9690
# Epoch 93/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0875 - accuracy: 0.9689
# Epoch 94/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0874 - accuracy: 0.9697
# Epoch 95/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0873 - accuracy: 0.9694
# Epoch 96/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0872 - accuracy: 0.9696
# Epoch 97/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0872 - accuracy: 0.9692
# Epoch 98/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0873 - accuracy: 0.9690
# Epoch 99/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0867 - accuracy: 0.9689
# Epoch 100/100
# 243/243 [==============================] - 1s 2ms/step - loss: 0.0870 - accuracy: 0.9692

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[1819   24]
#  [  55   41]]
# 0.9592573491490459

# %%
cm =confusion_matrix(y_test, y_pred)
sns.heatmap(cm, square=True , annot=True)
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1843
#            1       0.63      0.43      0.51        96
#
#     accuracy                           0.96      1939
#    macro avg       0.80      0.71      0.74      1939
# weighted avg       0.95      0.96      0.96      1939

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, y_pred) 
roc_auc = auc(fpr, tpr)

# %%
plt.figure()  
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--', label='No Skill')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Treatment-needed ROP Classification (ANN Model)')
plt.legend()
plt.show()

# %% [markdown]
# ## Feature importance analysis with Random-Forrest Classifier

# %%
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(criterion = 'entropy', random_state = 42)
rfc.fit(X_train, y_train)
# Out:
# C:\Users\user\miniconda3\lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(criterion='entropy', random_state=42)

# %%
rfc_pred_train = rfc.predict(X_train)
print('Training Set Evaluation F1-Score=>',f1_score(y_train,rfc_pred_train))
# Out:
# Training Set Evaluation F1-Score=> 1.0

# %%
rfc_pred_test = rfc.predict(X_test)
print('Testing Set Evaluation F1-Score=>',f1_score(y_test,rfc_pred_test))
# Out:
# Testing Set Evaluation F1-Score=> 0.5142857142857142

# %%
rfc.feature_importances_
# Out:
# array([1.95127060e-02, 3.78664163e-02, 3.86884944e-02, 2.10061725e-04,
#        2.45656765e-06, 1.52757196e-01, 1.52103527e-01, 1.80640922e-01,
#        7.09216672e-02, 9.99954191e-02, 6.95330384e-02, 6.79158935e-02,
#        1.09852202e-01])

# %%
feature_importance=pd.DataFrame({'rfc':rfc.feature_importances_},index=ROP_Dataset.columns[:-1])
feature_importance.sort_values(by='rfc',ascending=True,inplace=True)

index = np.arange(len(feature_importance))
fig, ax = plt.subplots(figsize=(18,8))
rfc_feature=ax.barh(index,feature_importance['rfc'],0.4,color='purple',label='Random Forest')
ax.set(yticks=index+0.4,yticklabels=feature_importance.index)

ax.legend()
plt.show()
